# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file = pd.read_csv('C:/Users/PISHTAAZ SOFTWARE/Desktop/Arash Rasouli/Arash1.csv')
file.head(25)
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1  3.0     145.0  233.0  1.0      0.0      150      0      2.3
# 1    37    1  2.0     130.0  250.0  0.0      1.0      187      0      3.5
# 2    41    0  1.0     130.0  204.0  0.0      0.0      172      0      1.4
# 3    56    1  1.0     120.0  236.0  0.0      1.0      178      0      0.8
# 4    57    0  0.0     120.0  354.0  0.0      1.0      163      1      0.6
# 5    57    1  0.0     140.0  192.0  0.0      1.0      148      0      0.4
# 6    56    0  1.0     140.0  294.0  0.0      0.0      153      0      1.3
# 7    44    1  1.0     120.0  263.0  0.0      1.0      173      0      0.0
# 8    52    1  2.0     172.0  199.0  1.0      1.0      162      0      0.5
# 9    57    1  2.0     150.0  168.0  0.0      1.0      174      0      1.6
# 10   54    1  0.0     140.0  239.0  0.0      1.0      160      0      1.2
# 11   48    0  2.0     130.0  275.0  0.0      1.0      139      0      0.2
# ...

# %%
import scipy.stats as stats

# %%
file['zr'] = stats.zscore(file['thalach'])

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        303 non-null    float64
#  1   sex        303 non-null    int64
#  2   cp         302 non-null    float64
#  3   trestbps   301 non-null    float64
#  4   chol       300 non-null    float64
#  5   fbs        302 non-null    float64
#  6   restecg    302 non-null    float64
#  7   thalach    303 non-null    int64
#  8   exang      303 non-null    int64
#  9   oldpeak    303 non-null    float64
#  10  slope      303 non-null    int64
#  11  ca         303 non-null    int64
#  12  thal       303 non-null    int64
#  13  target     303 non-null    int64
#  14  age_sqrt   303 non-null    float64
#  15  age_log    303 non-null    float64
#  16  chol_sqrt  300 non-null    float64
#  17  chol_log   300 non-null    float64
#  18  zr         303 non-null    float64
# ...

# %%
file[(file['zr'] < -3) | (file['zr']>3)]
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 272  67.0    1  0.0     120.0  237.0  0.0      1.0       71      0      1.0
#
#      slope  ca  thal  target  age_sqrt   age_log  chol_sqrt  chol_log  \
# 272      1   0     2       0  8.185353  4.204693  15.394804   5.46806
#
#            zr
# 272 -3.439267

# %%
file2 = file[(file['zr'] > -3) & (file['zr'] < 3)].reset_index()
file2
# Out:
#      index   age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0        0  40.0    1  3.0     145.0  233.0  1.0      0.0      150      0
# 1        1  37.0    1  2.0     130.0  250.0  0.0      1.0      187      0
# 2        2  41.0    0  1.0     130.0  204.0  0.0      0.0      172      0
# 3        3  56.0    1  1.0     120.0  236.0  0.0      1.0      178      0
# 4        4  57.0    0  0.0     120.0  354.0  0.0      1.0      163      1
# ..     ...   ...  ...  ...       ...    ...  ...      ...      ...    ...
# 297    298  57.0    0  0.0     140.0  241.0  0.0      1.0      123      1
# 298    299  45.0    1  3.0     110.0  264.0  0.0      1.0      132      0
# 299    300  68.0    1  0.0     144.0  193.0  1.0      1.0      141      0
# 300    301  57.0    1  0.0     130.0  131.0  0.0      1.0      115      1
# 301    302  57.0    0  1.0       NaN  236.0  0.0      0.0      174      0
#
#      oldpeak  slope  ca  thal  target  age_sqrt   age_log  chol_sqrt  \
# ...

# %%
file2['zr2'] = stats.zscore(file2['thalach'])

# %%
 file[(file['zr2'] < -3) | (file['zr2'] > 3)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\PycharmProjects\pythonProject2\venv\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'zr2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 file[(file['zr2'] < -3) | (file['zr2'] > 3)]
#
# ...

# %%
file['age'] = file['age'].astype('float')
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        303 non-null    float64
#  1   sex        303 non-null    int64
#  2   cp         302 non-null    float64
#  3   trestbps   301 non-null    float64
#  4   chol       300 non-null    float64
#  5   fbs        302 non-null    float64
#  6   restecg    302 non-null    float64
#  7   thalach    303 non-null    int64
#  8   exang      303 non-null    int64
#  9   oldpeak    303 non-null    float64
#  10  slope      303 non-null    int64
#  11  ca         303 non-null    int64
#  12  thal       303 non-null    int64
#  13  target     303 non-null    int64
#  14  age_sqrt   303 non-null    float64
#  15  age_log    303 non-null    float64
#  16  chol_sqrt  300 non-null    float64
#  17  chol_log   300 non-null    float64
#  18  zr         303 non-null    float64
# ...

# %%
file['chol_sqrt'] = np.sqrt(file['chol'])

# %%
file['chol'].plot(kind = 'hist',bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
file['chol'].skew()
# Out:
# 1.1361221758483282

# %%
file['chol_sqrt'].skew()
# Out:
# 0.5546669360790187

# %%
file['chol_sqrt'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
file['chol_log'] = np.log(file['chol'])

# %%
file['chol_log'].skew()
# Out:
# 0.07935955923301247

# %%
file['chol_log'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
file
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    40.0    1  3.0     145.0  233.0  1.0      0.0      150      0      2.3
# 1    37.0    1  2.0     130.0  250.0  0.0      1.0      187      0      3.5
# 2    41.0    0  1.0     130.0  204.0  0.0      0.0      172      0      1.4
# 3    56.0    1  1.0     120.0  236.0  0.0      1.0      178      0      0.8
# 4    57.0    0  0.0     120.0  354.0  0.0      1.0      163      1      0.6
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  57.0    0  0.0     140.0  241.0  0.0      1.0      123      1      0.2
# 299  45.0    1  3.0     110.0  264.0  0.0      1.0      132      0      1.2
# 300  68.0    1  0.0     144.0  193.0  1.0      1.0      141      0      3.4
# 301  57.0    1  0.0     130.0  131.0  0.0      1.0      115      1      1.2
# 302  57.0    0  1.0       NaN  236.0  0.0      0.0      174      0      0.0
#
#      slope  ca  thal  target  age_sqrt   age_log
# ...

# %%
file['age_log'].skew()
# Out:
# -0.46575215303655065

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        302 non-null    float64
#  3   trestbps  301 non-null    float64
#  4   chol      300 non-null    float64
#  5   fbs       302 non-null    float64
#  6   restecg   302 non-null    float64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(6), int64(8)
# memory usage: 33.3 KB

# %%
file.isnull().sum()
# Out:
# age         0
# sex         0
# cp          1
# trestbps    2
# chol        3
# fbs         1
# restecg     1
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
x = file.iloc[: , :-1].values
y = file.iloc[: , -1].values

# %%
from sklearn.impute import SimpleImputer 
si = SimpleImputer (missing_values = np.nan, strategy = 'median')
x = si.fit_transform(x)

# %%
ex = np.array([[41,0,1.0,130.0,204.0,np.nan,np.nan,172,0,1.4,2,0,2]])
si.transform(ex)
# Out:
# array([[ 41. ,   0. ,   1. , 130. , 204. ,   0. ,   1. , 172. ,   0. ,
#           1.4,   2. ,   0. ,   2. ]])

# %%
from sklearn.impute import KNNImputer

# %%
knn = KNNImputer(n_neighbors = 3)
x = knn.fit_transform(x)

# %%
ex = np.array([[41,0,1.0,130.0,204.0,np.nan,np.nan,172,0,1.4,2,0,2]])
knn.transform(ex)
# Out:
# array([[ 41.        ,   0.        ,   1.        , 130.        ,
#         204.        ,   0.        ,   0.33333333, 172.        ,
#           0.        ,   1.4       ,   2.        ,   0.        ,
#           2.        ]])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
ln = LabelEncoder()
new = ln.fit_transform(x[: , 0])

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
rew = ColumnTransformer([('target' ,OneHotEncoder(), [0])],remainder = 'passthrough')
re = rew.fit_transform(x)

# %%
re
# Out:
# <303x52 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2794 stored elements in Compressed Sparse Row format>

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
sc.fit_transform(x)
# Out:
# array([[-1.47840213,  0.68100522,  1.97279609, ..., -2.27457861,
#         -0.71442887, -2.14887271],
#        [-1.80253805,  0.68100522,  1.00083314, ..., -2.27457861,
#         -0.71442887, -0.51292188],
#        [-1.37035682, -1.46841752,  0.02887019, ...,  0.97635214,
#         -0.71442887, -0.51292188],
#        ...,
#        [ 1.54686648,  0.68100522, -0.94309277, ..., -0.64911323,
#          1.24459328,  1.12302895],
#        [ 0.3583681 ,  0.68100522, -0.94309277, ..., -0.64911323,
#          0.26508221,  1.12302895],
#        [ 0.3583681 , -1.46841752,  0.02887019, ..., -0.64911323,
#          0.26508221, -0.51292188]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn = MinMaxScaler(feature_range = (0,1))
mn.fit_transform(x)
# Out:
# array([[0.22916667, 1.        , 1.        , ..., 0.        , 0.        ,
#         0.33333333],
#        [0.16666667, 1.        , 0.66666667, ..., 0.        , 0.        ,
#         0.66666667],
#        [0.25      , 0.        , 0.33333333, ..., 1.        , 0.        ,
#         0.66666667],
#        ...,
#        [0.8125    , 1.        , 0.        , ..., 0.5       , 0.5       ,
#         1.        ],
#        [0.58333333, 1.        , 0.        , ..., 0.5       , 0.25      ,
#         1.        ],
#        [0.58333333, 0.        , 0.33333333, ..., 0.5       , 0.25      ,
#         0.66666667]])

# %%
import scipy.stats as stats

# %%
file['zr'] = stats.zscore(file['chol'])

# %%
# Out:
#      age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   40.0    1  3.0     145.0  233.0  1.0      0.0      150      0      2.3
# 1   37.0    1  2.0     130.0  250.0  0.0      1.0      187      0      3.5
# 2   41.0    0  1.0     130.0  204.0  0.0      0.0      172      0      1.4
# 3   56.0    1  1.0     120.0  236.0  0.0      1.0      178      0      0.8
# 4   57.0    0  0.0     120.0  354.0  0.0      1.0      163      1      0.6
# 5   57.0    1  0.0     140.0  192.0  0.0      1.0      148      0      0.4
# 6   56.0    0  1.0     140.0  294.0  0.0      0.0      153      0      1.3
# 7   44.0    1  1.0     120.0  263.0  0.0      1.0      173      0      0.0
# 8   52.0    1  2.0     172.0  199.0  1.0      1.0      162      0      0.5
# 9   57.0    1  2.0     150.0  168.0  0.0      1.0      174      0      1.6
# 10  54.0    1  0.0     140.0  239.0  0.0      1.0      160      0      1.2
# ...

# %%
file['chol'] = file['chol'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 file['chol'] = file['chol'].astype('int')
#
# File ~\PycharmProjects\pythonProject2\venv\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\PycharmProjects\pythonProject2\venv\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
# ...
